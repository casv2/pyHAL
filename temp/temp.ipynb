# %%
import pyHAL
import importlib
#importlib.reload(HAL)
from ase.io import read, write
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-8bde30fddb69> in <module>
# ----> 1 import pyHAL
#       2 import importlib
#       3 #importlib.reload(HAL)
#       4 from ase.io import read, write
#
# ~/miniconda3/lib/python3.8/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# ~/miniconda3/lib/python3.8/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~/miniconda3/lib/python3.8/importlib/_bootstrap.py in _find_spec(name, path, target)
#
# ~/miniconda3/lib/python3.8/importlib/_bootstrap_external.py in find_spec(cls, fullname, path, target)
#
# ~/miniconda3/lib/python3.8/importlib/_bootstrap_external.py in _get_spec(cls, fullname, path, target)
#
# ~/miniconda3/lib/python3.8/importlib/_bootstrap_external.py in _legacy_get_spec(cls, fullname, finder)
#
# ...

# %%
al = read("./temp/peg_all.xyz", ":")
at = al[0]

# %%
HAL.HAL(at, "bla", nsteps=1000, tau=0.01, dtau=0.1, ntau=100, varE_tol=0.3, dt=0.5, write_files=True)
# Out:
# 0 10.0
# 1 12.0
# 2 12.0
# 3 12.0
# 4 12.0
# 5 12.0
# 6 12.0
# 7 12.0
# 8 12.0
# 9 12.0
# /Users/Cas/miniconda3/lib/python3.8/site-packages/ase/io/extxyz.py:999: UserWarning: write_xyz() overwriting array "forces" present in atoms.arrays with stored results from calculator
#   warnings.warn('write_xyz() overwriting array "{0}" present '
